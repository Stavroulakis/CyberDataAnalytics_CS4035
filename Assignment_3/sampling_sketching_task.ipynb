# %%
import random
import pandas as pd
import collections
import operator
import mmh3
import math

aa= pd.read_csv('capture20110811.pcap.netflow.labeled',delimiter=' ')
columns=['Date','Duration','Protocol','Source','Dest','Label']
lst=[]
with open('capture20110811.pcap.netflow.labeled') as fp:  
    for cnt, line in enumerate(fp):
        if cnt!=0:
            dat=line.split("\t")
            lst.append([dat[0],dat[1],dat[2],dat[3].split(':')[0],dat[5].split(':')[0],dat[11].split('\n')[0]])
dataset=pd.DataFrame(lst, columns=columns)

# %%
# only malware
infected_host='147.32.84.165'
infected_dataset=dataset.loc[(dataset['Source']==infected_host) | (dataset['Dest']==infected_host)]
infected_dataset=infected_dataset.reset_index()

# %% [markdown]
# ### First we compute the 10 most frequently connected ips with the selected host
#
# which will be our ground truth form now on

# %%
def return_k_frequent_ips(dataset, k):
    ips=[]

    for i in range (0,len(dataset)):
        if (dataset.Source[i] == infected_host):
            ips.append(dataset.Dest[i])
        else:
            ips.append(dataset.Source[i])

    counter=collections.Counter(ips)
    return(counter.most_common(k), ips)

# %%
#find the 10 most frequently used ips except for the host
most_freq,ips = return_k_frequent_ips(infected_dataset, 10)
print(most_freq)
# Out:
# [('193.23.181.44', 6442), ('174.128.246.102', 4101), ('174.37.196.55', 3707), ('173.236.31.226', 3410), ('184.154.89.154', 3344), ('67.19.72.206', 3135), ('72.20.15.61', 2966), ('46.4.36.120', 1627), ('212.117.171.138', 967), ('147.32.80.9', 787)]

# %%
# print the number of connections and the percentage they posses in the whole dataset
for t in most_freq:
    print('number of connections:',t[1], 'percentile', t[1]*100.0/len(infected_dataset))
# Out:
# ('number of connections:', 6442, 'percentile', 12.434133065683568)
# ('number of connections:', 4101, 'percentile', 7.9156131174120326)
# ('number of connections:', 3707, 'percentile', 7.155127487502171)
# ('number of connections:', 3410, 'percentile', 6.581868015209713)
# ('number of connections:', 3344, 'percentile', 6.454477021366944)
# ('number of connections:', 3135, 'percentile', 6.05107220753151)
# ('number of connections:', 2966, 'percentile', 5.724874056631087)
# ('number of connections:', 1627, 'percentile', 3.1403810148815845)
# ('number of connections:', 967, 'percentile', 1.8664710764538979)
# ('number of connections:', 787, 'percentile', 1.5190410932463472)

# %% [markdown]
# ## The 10 most frequent ips with MIN-WISE sampling for different reservoir sizes

# %%
#MIN-WISE sampling
#select the k smallest values

for k in range(100, 10100, 100):
    for index, row in infected_dataset.iterrows():
        #begin by setting a random value at each row
        a = random.uniform(0,1)
        infected_dataset.set_value(index,'rn',a)

    sort_infections = infected_dataset.sort_values(['rn'], ascending=[True])
    sel_k = sort_infections[0:k]
    sel_k=sel_k.reset_index(level=0, drop=True)
    most_freq_minwise, ips_minwise = return_k_frequent_ips(sel_k, 10)
    print('=======> Value of reservoir:',k)
    print('Top 10:', most_freq_minwise)
    for t in most_freq_minwise:
        print('Element',t,'percentage', t[1]*100.0/k, '%')
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ('=======> Value of reservoir:', 100)
# ('Top 10:', [('193.23.181.44', 11), ('67.19.72.206', 10), ('174.37.196.55', 8), ('72.20.15.61', 7), ('174.128.246.102', 5), ('147.32.80.9', 4), ('212.117.171.138', 4), ('46.4.36.120', 3), ('173.192.170.88', 3), ('173.236.31.226', 2)])
# ('Element', ('193.23.181.44', 11), 'percentage', 11.0, '%')
# ('Element', ('67.19.72.206', 10), 'percentage', 10.0, '%')
# ('Element', ('174.37.196.55', 8), 'percentage', 8.0, '%')
# ('Element', ('72.20.15.61', 7), 'percentage', 7.0, '%')
# ('Element', ('174.128.246.102', 5), 'percentage', 5.0, '%')
# ('Element', ('147.32.80.9', 4), 'percentage', 4.0, '%')
# ('Element', ('212.117.171.138', 4), 'percentage', 4.0, '%')
# ('Element', ('46.4.36.120', 3), 'percentage', 3.0, '%')
# ('Element', ('173.192.170.88', 3), 'percentage', 3.0, '%')
# ('Element', ('173.236.31.226', 2), 'percentage', 2.0, '%')
# ('=======> Value of reservoir:', 200)
# ('Top 10:', [('193.23.181.44', 28), ('174.128.246.102', 15), ('67.19.72.206', 15), ('72.20.15.61', 12), ('174.37.196.55', 12), ('173.236.31.226', 9), ('184.154.89.154', 9), ('147.32.80.9', 7), ('173.192.170.88', 5), ('217.163.21.37', 3)])
# ('Element', ('193.23.181.44', 28), 'percentage', 14.0, '%')
# ('Element', ('174.128.246.102', 15), 'percentage', 7.5, '%')
# ('Element', ('67.19.72.206', 15), 'percentage', 7.5, '%')
# ('Element', ('72.20.15.61', 12), 'percentage', 6.0, '%')
# ('Element', ('174.37.196.55', 12), 'percentage', 6.0, '%')
# ('Element', ('173.236.31.226', 9), 'percentage', 4.5, '%')
# ('Element', ('184.154.89.154', 9), 'percentage', 4.5, '%')
# ('Element', ('147.32.80.9', 7), 'percentage', 3.5, '%')
# ('Element', ('173.192.170.88', 5), 'percentage', 2.5, '%')
# ('Element', ('217.163.21.37', 3), 'percentage', 1.5, '%')
# ('=======> Value of reservoir:', 300)
# ('Top 10:', [('193.23.181.44', 37), ('174.128.246.102', 27), ('174.37.196.55', 25), ('67.19.72.206', 21), ('184.154.89.154', 18), ('72.20.15.61', 18), ('173.236.31.226', 12), ('46.4.36.120', 10), ('173.192.170.88', 8), ('64.12.90.97', 7)])
# ('Element', ('193.23.181.44', 37), 'percentage', 12.333333333333334, '%')
# ('Element', ('174.128.246.102', 27), 'percentage', 9.0, '%')
# ('Element', ('174.37.196.55', 25), 'percentage', 8.333333333333334, '%')
# ('Element', ('67.19.72.206', 21), 'percentage', 7.0, '%')
# ('Element', ('184.154.89.154', 18), 'percentage', 6.0, '%')
# ('Element', ('72.20.15.61', 18), 'percentage', 6.0, '%')
# ('Element', ('173.236.31.226', 12), 'percentage', 4.0, '%')
# ('Element', ('46.4.36.120', 10), 'percentage', 3.3333333333333335, '%')
# ('Element', ('173.192.170.88', 8), 'percentage', 2.6666666666666665, '%')
# ('Element', ('64.12.90.97', 7), 'percentage', 2.3333333333333335, '%')
# ('=======> Value of reservoir:', 400)
# ('Top 10:', [('193.23.181.44', 53), ('174.37.196.55', 30), ('174.128.246.102', 28), ('67.19.72.206', 25), ('173.236.31.226', 24), ('184.154.89.154', 22), ('72.20.15.61', 16), ('46.4.36.120', 15), ('212.117.171.138', 12), ('217.163.21.37', 8)])
# ('Element', ('193.23.181.44', 53), 'percentage', 13.25, '%')
# ('Element', ('174.37.196.55', 30), 'percentage', 7.5, '%')
# ('Element', ('174.128.246.102', 28), 'percentage', 7.0, '%')
# ('Element', ('67.19.72.206', 25), 'percentage', 6.25, '%')
# ('Element', ('173.236.31.226', 24), 'percentage', 6.0, '%')
# ('Element', ('184.154.89.154', 22), 'percentage', 5.5, '%')
# ('Element', ('72.20.15.61', 16), 'percentage', 4.0, '%')
# ('Element', ('46.4.36.120', 15), 'percentage', 3.75, '%')
# ('Element', ('212.117.171.138', 12), 'percentage', 3.0, '%')
# ('Element', ('217.163.21.37', 8), 'percentage', 2.0, '%')
# ('=======> Value of reservoir:', 500)
# ('Top 10:', [('193.23.181.44', 75), ('67.19.72.206', 34), ('184.154.89.154', 33), ('174.128.246.102', 33), ('173.236.31.226', 33), ('174.37.196.55', 31), ('46.4.36.120', 23), ('72.20.15.61', 22), ('217.163.21.36', 11), ('64.12.90.33', 10)])
# ('Element', ('193.23.181.44', 75), 'percentage', 15.0, '%')
# ('Element', ('67.19.72.206', 34), 'percentage', 6.8, '%')
# ('Element', ('184.154.89.154', 33), 'percentage', 6.6, '%')
# ('Element', ('174.128.246.102', 33), 'percentage', 6.6, '%')
# ('Element', ('173.236.31.226', 33), 'percentage', 6.6, '%')
# ('Element', ('174.37.196.55', 31), 'percentage', 6.2, '%')
# ('Element', ('46.4.36.120', 23), 'percentage', 4.6, '%')
# ('Element', ('72.20.15.61', 22), 'percentage', 4.4, '%')
# ('Element', ('217.163.21.36', 11), 'percentage', 2.2, '%')
# ('Element', ('64.12.90.33', 10), 'percentage', 2.0, '%')
# ('=======> Value of reservoir:', 600)
# ('Top 10:', [('193.23.181.44', 66), ('174.128.246.102', 57), ('174.37.196.55', 52), ('67.19.72.206', 40), ('184.154.89.154', 37), ('173.236.31.226', 33), ('72.20.15.61', 27), ('46.4.36.120', 16), ('212.117.171.138', 15), ('173.192.170.88', 12)])
# ('Element', ('193.23.181.44', 66), 'percentage', 11.0, '%')
# ('Element', ('174.128.246.102', 57), 'percentage', 9.5, '%')
# ('Element', ('174.37.196.55', 52), 'percentage', 8.666666666666666, '%')
# ('Element', ('67.19.72.206', 40), 'percentage', 6.666666666666667, '%')
# ('Element', ('184.154.89.154', 37), 'percentage', 6.166666666666667, '%')
# ('Element', ('173.236.31.226', 33), 'percentage', 5.5, '%')
# ('Element', ('72.20.15.61', 27), 'percentage', 4.5, '%')
# ('Element', ('46.4.36.120', 16), 'percentage', 2.6666666666666665, '%')
# ('Element', ('212.117.171.138', 15), 'percentage', 2.5, '%')
# ('Element', ('173.192.170.88', 12), 'percentage', 2.0, '%')
# ('=======> Value of reservoir:', 700)
# ('Top 10:', [('193.23.181.44', 87), ('173.236.31.226', 69), ('174.37.196.55', 57), ('184.154.89.154', 51), ('174.128.246.102', 47), ('72.20.15.61', 44), ('67.19.72.206', 35), ('46.4.36.120', 19), ('212.117.171.138', 14), ('147.32.80.9', 12)])
# ('Element', ('193.23.181.44', 87), 'percentage', 12.428571428571429, '%')
# ('Element', ('173.236.31.226', 69), 'percentage', 9.857142857142858, '%')
# ('Element', ('174.37.196.55', 57), 'percentage', 8.142857142857142, '%')
# ('Element', ('184.154.89.154', 51), 'percentage', 7.285714285714286, '%')
# ('Element', ('174.128.246.102', 47), 'percentage', 6.714285714285714, '%')
# ('Element', ('72.20.15.61', 44), 'percentage', 6.285714285714286, '%')
# ('Element', ('67.19.72.206', 35), 'percentage', 5.0, '%')
# ('Element', ('46.4.36.120', 19), 'percentage', 2.7142857142857144, '%')
# ('Element', ('212.117.171.138', 14), 'percentage', 2.0, '%')
# ('Element', ('147.32.80.9', 12), 'percentage', 1.7142857142857142, '%')
# ('=======> Value of reservoir:', 800)
# ('Top 10:', [('193.23.181.44', 103), ('174.37.196.55', 69), ('174.128.246.102', 56), ('173.236.31.226', 53), ('184.154.89.154', 50), ('72.20.15.61', 43), ('67.19.72.206', 42), ('46.4.36.120', 27), ('217.163.21.37', 17), ('147.32.80.9', 16)])
# ('Element', ('193.23.181.44', 103), 'percentage', 12.875, '%')
# ('Element', ('174.37.196.55', 69), 'percentage', 8.625, '%')
# ('Element', ('174.128.246.102', 56), 'percentage', 7.0, '%')
# ('Element', ('173.236.31.226', 53), 'percentage', 6.625, '%')
# ('Element', ('184.154.89.154', 50), 'percentage', 6.25, '%')
# ('Element', ('72.20.15.61', 43), 'percentage', 5.375, '%')
# ('Element', ('67.19.72.206', 42), 'percentage', 5.25, '%')
# ('Element', ('46.4.36.120', 27), 'percentage', 3.375, '%')
# ('Element', ('217.163.21.37', 17), 'percentage', 2.125, '%')
# ('Element', ('147.32.80.9', 16), 'percentage', 2.0, '%')
# ('=======> Value of reservoir:', 900)
# ('Top 10:', [('193.23.181.44', 104), ('174.37.196.55', 74), ('174.128.246.102', 69), ('184.154.89.154', 63), ('67.19.72.206', 53), ('173.236.31.226', 52), ('72.20.15.61', 50), ('46.4.36.120', 29), ('212.117.171.138', 22), ('217.163.21.36', 13)])
# ('Element', ('193.23.181.44', 104), 'percentage', 11.555555555555555, '%')
# ('Element', ('174.37.196.55', 74), 'percentage', 8.222222222222221, '%')
# ('Element', ('174.128.246.102', 69), 'percentage', 7.666666666666667, '%')
# ('Element', ('184.154.89.154', 63), 'percentage', 7.0, '%')
# ('Element', ('67.19.72.206', 53), 'percentage', 5.888888888888889, '%')
# ('Element', ('173.236.31.226', 52), 'percentage', 5.777777777777778, '%')
# ('Element', ('72.20.15.61', 50), 'percentage', 5.555555555555555, '%')
# ('Element', ('46.4.36.120', 29), 'percentage', 3.2222222222222223, '%')
# ('Element', ('212.117.171.138', 22), 'percentage', 2.4444444444444446, '%')
# ('Element', ('217.163.21.36', 13), 'percentage', 1.4444444444444444, '%')
# ('=======> Value of reservoir:', 1000)
# ('Top 10:', [('193.23.181.44', 112), ('174.128.246.102', 99), ('173.236.31.226', 80), ('67.19.72.206', 67), ('72.20.15.61', 59), ('184.154.89.154', 56), ('174.37.196.55', 56), ('46.4.36.120', 28), ('212.117.171.138', 21), ('217.163.21.36', 19)])
# ('Element', ('193.23.181.44', 112), 'percentage', 11.2, '%')
# ('Element', ('174.128.246.102', 99), 'percentage', 9.9, '%')
# ('Element', ('173.236.31.226', 80), 'percentage', 8.0, '%')
# ('Element', ('67.19.72.206', 67), 'percentage', 6.7, '%')
# ('Element', ('72.20.15.61', 59), 'percentage', 5.9, '%')
# ('Element', ('184.154.89.154', 56), 'percentage', 5.6, '%')
# ('Element', ('174.37.196.55', 56), 'percentage', 5.6, '%')
# ('Element', ('46.4.36.120', 28), 'percentage', 2.8, '%')
# ('Element', ('212.117.171.138', 21), 'percentage', 2.1, '%')
# ('Element', ('217.163.21.36', 19), 'percentage', 1.9, '%')
# ('=======> Value of reservoir:', 1100)
# ('Top 10:', [('193.23.181.44', 124), ('184.154.89.154', 86), ('174.37.196.55', 74), ('174.128.246.102', 70), ('173.236.31.226', 70), ('67.19.72.206', 69), ('72.20.15.61', 58), ('46.4.36.120', 38), ('212.117.171.138', 27), ('147.32.80.9', 26)])
# ('Element', ('193.23.181.44', 124), 'percentage', 11.272727272727273, '%')
# ('Element', ('184.154.89.154', 86), 'percentage', 7.818181818181818, '%')
# ('Element', ('174.37.196.55', 74), 'percentage', 6.7272727272727275, '%')
# ('Element', ('174.128.246.102', 70), 'percentage', 6.363636363636363, '%')
# ('Element', ('173.236.31.226', 70), 'percentage', 6.363636363636363, '%')
# ('Element', ('67.19.72.206', 69), 'percentage', 6.2727272727272725, '%')
# ('Element', ('72.20.15.61', 58), 'percentage', 5.2727272727272725, '%')
# ('Element', ('46.4.36.120', 38), 'percentage', 3.4545454545454546, '%')
# ('Element', ('212.117.171.138', 27), 'percentage', 2.4545454545454546, '%')
# ('Element', ('147.32.80.9', 26), 'percentage', 2.3636363636363638, '%')
# ('=======> Value of reservoir:', 1200)
# ('Top 10:', [('193.23.181.44', 162), ('174.128.246.102', 89), ('184.154.89.154', 79), ('174.37.196.55', 73), ('67.19.72.206', 71), ('72.20.15.61', 69), ('173.236.31.226', 67), ('46.4.36.120', 32), ('212.117.171.138', 26), ('184.82.148.44', 19)])
# ('Element', ('193.23.181.44', 162), 'percentage', 13.5, '%')
# ('Element', ('174.128.246.102', 89), 'percentage', 7.416666666666667, '%')
# ('Element', ('184.154.89.154', 79), 'percentage', 6.583333333333333, '%')
# ('Element', ('174.37.196.55', 73), 'percentage', 6.083333333333333, '%')
# ('Element', ('67.19.72.206', 71), 'percentage', 5.916666666666667, '%')
# ('Element', ('72.20.15.61', 69), 'percentage', 5.75, '%')
# ('Element', ('173.236.31.226', 67), 'percentage', 5.583333333333333, '%')
# ('Element', ('46.4.36.120', 32), 'percentage', 2.6666666666666665, '%')
# ('Element', ('212.117.171.138', 26), 'percentage', 2.1666666666666665, '%')
# ('Element', ('184.82.148.44', 19), 'percentage', 1.5833333333333333, '%')
# ('=======> Value of reservoir:', 1300)
# ('Top 10:', [('193.23.181.44', 146), ('174.128.246.102', 104), ('174.37.196.55', 96), ('67.19.72.206', 83), ('173.236.31.226', 81), ('72.20.15.61', 75), ('184.154.89.154', 68), ('46.4.36.120', 37), ('212.117.171.138', 27), ('173.192.170.88', 25)])
# ('Element', ('193.23.181.44', 146), 'percentage', 11.23076923076923, '%')
# ('Element', ('174.128.246.102', 104), 'percentage', 8.0, '%')
# ('Element', ('174.37.196.55', 96), 'percentage', 7.384615384615385, '%')
# ('Element', ('67.19.72.206', 83), 'percentage', 6.384615384615385, '%')
# ('Element', ('173.236.31.226', 81), 'percentage', 6.230769230769231, '%')
# ('Element', ('72.20.15.61', 75), 'percentage', 5.769230769230769, '%')
# ('Element', ('184.154.89.154', 68), 'percentage', 5.230769230769231, '%')
# ('Element', ('46.4.36.120', 37), 'percentage', 2.8461538461538463, '%')
# ('Element', ('212.117.171.138', 27), 'percentage', 2.076923076923077, '%')
# ('Element', ('173.192.170.88', 25), 'percentage', 1.9230769230769231, '%')
# ('=======> Value of reservoir:', 1400)
# ('Top 10:', [('193.23.181.44', 192), ('174.128.246.102', 122), ('174.37.196.55', 101), ('184.154.89.154', 88), ('72.20.15.61', 83), ('173.236.31.226', 80), ('67.19.72.206', 80), ('46.4.36.120', 41), ('147.32.80.9', 24), ('212.117.171.138', 23)])
# ('Element', ('193.23.181.44', 192), 'percentage', 13.714285714285714, '%')
# ('Element', ('174.128.246.102', 122), 'percentage', 8.714285714285714, '%')
# ('Element', ('174.37.196.55', 101), 'percentage', 7.214285714285714, '%')
# ('Element', ('184.154.89.154', 88), 'percentage', 6.285714285714286, '%')
# ('Element', ('72.20.15.61', 83), 'percentage', 5.928571428571429, '%')
# ('Element', ('173.236.31.226', 80), 'percentage', 5.714285714285714, '%')
# ('Element', ('67.19.72.206', 80), 'percentage', 5.714285714285714, '%')
# ('Element', ('46.4.36.120', 41), 'percentage', 2.9285714285714284, '%')
# ('Element', ('147.32.80.9', 24), 'percentage', 1.7142857142857142, '%')
# ('Element', ('212.117.171.138', 23), 'percentage', 1.6428571428571428, '%')
# ('=======> Value of reservoir:', 1500)
# ('Top 10:', [('193.23.181.44', 191), ('174.37.196.55', 124), ('174.128.246.102', 118), ('184.154.89.154', 97), ('173.236.31.226', 88), ('72.20.15.61', 87), ('67.19.72.206', 77), ('46.4.36.120', 50), ('212.117.171.138', 33), ('217.163.21.37', 29)])
# ('Element', ('193.23.181.44', 191), 'percentage', 12.733333333333333, '%')
# ('Element', ('174.37.196.55', 124), 'percentage', 8.266666666666667, '%')
# ('Element', ('174.128.246.102', 118), 'percentage', 7.866666666666666, '%')
# ('Element', ('184.154.89.154', 97), 'percentage', 6.466666666666667, '%')
# ('Element', ('173.236.31.226', 88), 'percentage', 5.866666666666666, '%')
# ('Element', ('72.20.15.61', 87), 'percentage', 5.8, '%')
# ('Element', ('67.19.72.206', 77), 'percentage', 5.133333333333334, '%')
# ('Element', ('46.4.36.120', 50), 'percentage', 3.3333333333333335, '%')
# ('Element', ('212.117.171.138', 33), 'percentage', 2.2, '%')
# ('Element', ('217.163.21.37', 29), 'percentage', 1.9333333333333333, '%')
# ('=======> Value of reservoir:', 1600)
# ('Top 10:', [('193.23.181.44', 193), ('174.128.246.102', 140), ('174.37.196.55', 105), ('173.236.31.226', 99), ('72.20.15.61', 99), ('67.19.72.206', 96), ('184.154.89.154', 85), ('46.4.36.120', 61), ('212.117.171.138', 26), ('147.32.80.9', 23)])
# ('Element', ('193.23.181.44', 193), 'percentage', 12.0625, '%')
# ('Element', ('174.128.246.102', 140), 'percentage', 8.75, '%')
# ('Element', ('174.37.196.55', 105), 'percentage', 6.5625, '%')
# ('Element', ('173.236.31.226', 99), 'percentage', 6.1875, '%')
# ('Element', ('72.20.15.61', 99), 'percentage', 6.1875, '%')
# ('Element', ('67.19.72.206', 96), 'percentage', 6.0, '%')
# ('Element', ('184.154.89.154', 85), 'percentage', 5.3125, '%')
# ('Element', ('46.4.36.120', 61), 'percentage', 3.8125, '%')
# ('Element', ('212.117.171.138', 26), 'percentage', 1.625, '%')
# ('Element', ('147.32.80.9', 23), 'percentage', 1.4375, '%')
# ('=======> Value of reservoir:', 1700)
# ('Top 10:', [('193.23.181.44', 209), ('174.128.246.102', 130), ('173.236.31.226', 120), ('184.154.89.154', 116), ('72.20.15.61', 116), ('67.19.72.206', 111), ('174.37.196.55', 109), ('46.4.36.120', 47), ('212.117.171.138', 29), ('173.192.170.88', 28)])
# ('Element', ('193.23.181.44', 209), 'percentage', 12.294117647058824, '%')
# ('Element', ('174.128.246.102', 130), 'percentage', 7.647058823529412, '%')
# ('Element', ('173.236.31.226', 120), 'percentage', 7.0588235294117645, '%')
# ('Element', ('184.154.89.154', 116), 'percentage', 6.823529411764706, '%')
# ('Element', ('72.20.15.61', 116), 'percentage', 6.823529411764706, '%')
# ('Element', ('67.19.72.206', 111), 'percentage', 6.529411764705882, '%')
# ('Element', ('174.37.196.55', 109), 'percentage', 6.411764705882353, '%')
# ('Element', ('46.4.36.120', 47), 'percentage', 2.764705882352941, '%')
# ('Element', ('212.117.171.138', 29), 'percentage', 1.7058823529411764, '%')
# ('Element', ('173.192.170.88', 28), 'percentage', 1.6470588235294117, '%')
# ('=======> Value of reservoir:', 1800)
# ('Top 10:', [('193.23.181.44', 204), ('174.128.246.102', 158), ('174.37.196.55', 140), ('184.154.89.154', 139), ('173.236.31.226', 128), ('72.20.15.61', 95), ('67.19.72.206', 90), ('46.4.36.120', 57), ('212.117.171.138', 35), ('147.32.80.9', 27)])
# ('Element', ('193.23.181.44', 204), 'percentage', 11.333333333333334, '%')
# ('Element', ('174.128.246.102', 158), 'percentage', 8.777777777777779, '%')
# ('Element', ('174.37.196.55', 140), 'percentage', 7.777777777777778, '%')
# ('Element', ('184.154.89.154', 139), 'percentage', 7.722222222222222, '%')
# ('Element', ('173.236.31.226', 128), 'percentage', 7.111111111111111, '%')
# ('Element', ('72.20.15.61', 95), 'percentage', 5.277777777777778, '%')
# ('Element', ('67.19.72.206', 90), 'percentage', 5.0, '%')
# ('Element', ('46.4.36.120', 57), 'percentage', 3.1666666666666665, '%')
# ('Element', ('212.117.171.138', 35), 'percentage', 1.9444444444444444, '%')
# ('Element', ('147.32.80.9', 27), 'percentage', 1.5, '%')
# ('=======> Value of reservoir:', 1900)
# ('Top 10:', [('193.23.181.44', 199), ('174.37.196.55', 150), ('174.128.246.102', 147), ('173.236.31.226', 132), ('67.19.72.206', 123), ('184.154.89.154', 120), ('72.20.15.61', 105), ('46.4.36.120', 61), ('212.117.171.138', 37), ('173.192.170.88', 26)])
# ('Element', ('193.23.181.44', 199), 'percentage', 10.473684210526315, '%')
# ('Element', ('174.37.196.55', 150), 'percentage', 7.894736842105263, '%')
# ('Element', ('174.128.246.102', 147), 'percentage', 7.7368421052631575, '%')
# ('Element', ('173.236.31.226', 132), 'percentage', 6.947368421052632, '%')
# ('Element', ('67.19.72.206', 123), 'percentage', 6.473684210526316, '%')
# ('Element', ('184.154.89.154', 120), 'percentage', 6.315789473684211, '%')
# ('Element', ('72.20.15.61', 105), 'percentage', 5.526315789473684, '%')
# ('Element', ('46.4.36.120', 61), 'percentage', 3.210526315789474, '%')
# ('Element', ('212.117.171.138', 37), 'percentage', 1.9473684210526316, '%')
# ('Element', ('173.192.170.88', 26), 'percentage', 1.368421052631579, '%')
# ('=======> Value of reservoir:', 2000)
# ('Top 10:', [('193.23.181.44', 225), ('174.128.246.102', 158), ('173.236.31.226', 140), ('174.37.196.55', 137), ('184.154.89.154', 136), ('67.19.72.206', 125), ('72.20.15.61', 113), ('46.4.36.120', 70), ('173.192.170.88', 32), ('217.163.21.36', 29)])
# ('Element', ('193.23.181.44', 225), 'percentage', 11.25, '%')
# ('Element', ('174.128.246.102', 158), 'percentage', 7.9, '%')
# ('Element', ('173.236.31.226', 140), 'percentage', 7.0, '%')
# ('Element', ('174.37.196.55', 137), 'percentage', 6.85, '%')
# ('Element', ('184.154.89.154', 136), 'percentage', 6.8, '%')
# ('Element', ('67.19.72.206', 125), 'percentage', 6.25, '%')
# ('Element', ('72.20.15.61', 113), 'percentage', 5.65, '%')
# ('Element', ('46.4.36.120', 70), 'percentage', 3.5, '%')
# ('Element', ('173.192.170.88', 32), 'percentage', 1.6, '%')
# ('Element', ('217.163.21.36', 29), 'percentage', 1.45, '%')
# ('=======> Value of reservoir:', 2100)
# ('Top 10:', [('193.23.181.44', 275), ('174.128.246.102', 168), ('72.20.15.61', 136), ('174.37.196.55', 133), ('184.154.89.154', 129), ('173.236.31.226', 129), ('67.19.72.206', 116), ('46.4.36.120', 67), ('212.117.171.138', 34), ('147.32.80.9', 31)])
# ('Element', ('193.23.181.44', 275), 'percentage', 13.095238095238095, '%')
# ('Element', ('174.128.246.102', 168), 'percentage', 8.0, '%')
# ('Element', ('72.20.15.61', 136), 'percentage', 6.476190476190476, '%')
# ('Element', ('174.37.196.55', 133), 'percentage', 6.333333333333333, '%')
# ('Element', ('184.154.89.154', 129), 'percentage', 6.142857142857143, '%')
# ('Element', ('173.236.31.226', 129), 'percentage', 6.142857142857143, '%')
# ('Element', ('67.19.72.206', 116), 'percentage', 5.523809523809524, '%')
# ('Element', ('46.4.36.120', 67), 'percentage', 3.1904761904761907, '%')
# ('Element', ('212.117.171.138', 34), 'percentage', 1.619047619047619, '%')
# ('Element', ('147.32.80.9', 31), 'percentage', 1.4761904761904763, '%')
# ('=======> Value of reservoir:', 2200)
# ('Top 10:', [('193.23.181.44', 285), ('174.128.246.102', 196), ('174.37.196.55', 171), ('184.154.89.154', 139), ('173.236.31.226', 136), ('67.19.72.206', 134), ('72.20.15.61', 130), ('46.4.36.120', 62), ('212.117.171.138', 42), ('217.163.21.36', 33)])
# ('Element', ('193.23.181.44', 285), 'percentage', 12.954545454545455, '%')
# ('Element', ('174.128.246.102', 196), 'percentage', 8.909090909090908, '%')
# ('Element', ('174.37.196.55', 171), 'percentage', 7.7727272727272725, '%')
# ('Element', ('184.154.89.154', 139), 'percentage', 6.318181818181818, '%')
# ('Element', ('173.236.31.226', 136), 'percentage', 6.181818181818182, '%')
# ('Element', ('67.19.72.206', 134), 'percentage', 6.090909090909091, '%')
# ('Element', ('72.20.15.61', 130), 'percentage', 5.909090909090909, '%')
# ('Element', ('46.4.36.120', 62), 'percentage', 2.8181818181818183, '%')
# ('Element', ('212.117.171.138', 42), 'percentage', 1.9090909090909092, '%')
# ('Element', ('217.163.21.36', 33), 'percentage', 1.5, '%')
# ('=======> Value of reservoir:', 2300)
# ('Top 10:', [('193.23.181.44', 260), ('174.128.246.102', 182), ('184.154.89.154', 158), ('174.37.196.55', 157), ('173.236.31.226', 154), ('67.19.72.206', 138), ('72.20.15.61', 135), ('46.4.36.120', 69), ('212.117.171.138', 41), ('217.163.21.37', 35)])
# ('Element', ('193.23.181.44', 260), 'percentage', 11.304347826086957, '%')
# ('Element', ('174.128.246.102', 182), 'percentage', 7.913043478260869, '%')
# ('Element', ('184.154.89.154', 158), 'percentage', 6.869565217391305, '%')
# ('Element', ('174.37.196.55', 157), 'percentage', 6.826086956521739, '%')
# ('Element', ('173.236.31.226', 154), 'percentage', 6.695652173913044, '%')
# ('Element', ('67.19.72.206', 138), 'percentage', 6.0, '%')
# ('Element', ('72.20.15.61', 135), 'percentage', 5.869565217391305, '%')
# ('Element', ('46.4.36.120', 69), 'percentage', 3.0, '%')
# ('Element', ('212.117.171.138', 41), 'percentage', 1.7826086956521738, '%')
# ('Element', ('217.163.21.37', 35), 'percentage', 1.5217391304347827, '%')
# ('=======> Value of reservoir:', 2400)
# ('Top 10:', [('193.23.181.44', 313), ('174.128.246.102', 171), ('173.236.31.226', 166), ('174.37.196.55', 155), ('184.154.89.154', 147), ('72.20.15.61', 147), ('67.19.72.206', 146), ('46.4.36.120', 84), ('212.117.171.138', 53), ('147.32.80.9', 33)])
# ('Element', ('193.23.181.44', 313), 'percentage', 13.041666666666666, '%')
# ('Element', ('174.128.246.102', 171), 'percentage', 7.125, '%')
# ('Element', ('173.236.31.226', 166), 'percentage', 6.916666666666667, '%')
# ('Element', ('174.37.196.55', 155), 'percentage', 6.458333333333333, '%')
# ('Element', ('184.154.89.154', 147), 'percentage', 6.125, '%')
# ('Element', ('72.20.15.61', 147), 'percentage', 6.125, '%')
# ('Element', ('67.19.72.206', 146), 'percentage', 6.083333333333333, '%')
# ('Element', ('46.4.36.120', 84), 'percentage', 3.5, '%')
# ('Element', ('212.117.171.138', 53), 'percentage', 2.2083333333333335, '%')
# ('Element', ('147.32.80.9', 33), 'percentage', 1.375, '%')
# ('=======> Value of reservoir:', 2500)
# ('Top 10:', [('193.23.181.44', 297), ('174.128.246.102', 203), ('174.37.196.55', 175), ('184.154.89.154', 169), ('173.236.31.226', 167), ('67.19.72.206', 155), ('72.20.15.61', 124), ('46.4.36.120', 70), ('212.117.171.138', 52), ('173.192.170.88', 38)])
# ('Element', ('193.23.181.44', 297), 'percentage', 11.88, '%')
# ('Element', ('174.128.246.102', 203), 'percentage', 8.12, '%')
# ('Element', ('174.37.196.55', 175), 'percentage', 7.0, '%')
# ('Element', ('184.154.89.154', 169), 'percentage', 6.76, '%')
# ('Element', ('173.236.31.226', 167), 'percentage', 6.68, '%')
# ('Element', ('67.19.72.206', 155), 'percentage', 6.2, '%')
# ('Element', ('72.20.15.61', 124), 'percentage', 4.96, '%')
# ('Element', ('46.4.36.120', 70), 'percentage', 2.8, '%')
# ('Element', ('212.117.171.138', 52), 'percentage', 2.08, '%')
# ('Element', ('173.192.170.88', 38), 'percentage', 1.52, '%')
# ('=======> Value of reservoir:', 2600)
# ('Top 10:', [('193.23.181.44', 316), ('174.128.246.102', 208), ('174.37.196.55', 181), ('173.236.31.226', 173), ('184.154.89.154', 172), ('67.19.72.206', 163), ('72.20.15.61', 144), ('46.4.36.120', 80), ('217.163.21.37', 43), ('74.6.136.244', 40)])
# ('Element', ('193.23.181.44', 316), 'percentage', 12.153846153846153, '%')
# ('Element', ('174.128.246.102', 208), 'percentage', 8.0, '%')
# ('Element', ('174.37.196.55', 181), 'percentage', 6.961538461538462, '%')
# ('Element', ('173.236.31.226', 173), 'percentage', 6.653846153846154, '%')
# ('Element', ('184.154.89.154', 172), 'percentage', 6.615384615384615, '%')
# ('Element', ('67.19.72.206', 163), 'percentage', 6.269230769230769, '%')
# ('Element', ('72.20.15.61', 144), 'percentage', 5.538461538461538, '%')
# ('Element', ('46.4.36.120', 80), 'percentage', 3.076923076923077, '%')
# ('Element', ('217.163.21.37', 43), 'percentage', 1.6538461538461537, '%')
# ('Element', ('74.6.136.244', 40), 'percentage', 1.5384615384615385, '%')
# ('=======> Value of reservoir:', 2700)
# ('Top 10:', [('193.23.181.44', 329), ('174.128.246.102', 210), ('174.37.196.55', 190), ('173.236.31.226', 189), ('72.20.15.61', 176), ('184.154.89.154', 175), ('67.19.72.206', 159), ('46.4.36.120', 76), ('212.117.171.138', 42), ('147.32.80.9', 40)])
# ('Element', ('193.23.181.44', 329), 'percentage', 12.185185185185185, '%')
# ('Element', ('174.128.246.102', 210), 'percentage', 7.777777777777778, '%')
# ('Element', ('174.37.196.55', 190), 'percentage', 7.037037037037037, '%')
# ('Element', ('173.236.31.226', 189), 'percentage', 7.0, '%')
# ('Element', ('72.20.15.61', 176), 'percentage', 6.518518518518518, '%')
# ('Element', ('184.154.89.154', 175), 'percentage', 6.481481481481482, '%')
# ('Element', ('67.19.72.206', 159), 'percentage', 5.888888888888889, '%')
# ('Element', ('46.4.36.120', 76), 'percentage', 2.814814814814815, '%')
# ('Element', ('212.117.171.138', 42), 'percentage', 1.5555555555555556, '%')
# ('Element', ('147.32.80.9', 40), 'percentage', 1.4814814814814814, '%')
# ('=======> Value of reservoir:', 2800)
# ('Top 10:', [('193.23.181.44', 337), ('174.128.246.102', 222), ('174.37.196.55', 204), ('173.236.31.226', 183), ('67.19.72.206', 171), ('184.154.89.154', 168), ('72.20.15.61', 148), ('46.4.36.120', 77), ('173.192.170.88', 52), ('212.117.171.138', 50)])
# ('Element', ('193.23.181.44', 337), 'percentage', 12.035714285714286, '%')
# ('Element', ('174.128.246.102', 222), 'percentage', 7.928571428571429, '%')
# ('Element', ('174.37.196.55', 204), 'percentage', 7.285714285714286, '%')
# ('Element', ('173.236.31.226', 183), 'percentage', 6.535714285714286, '%')
# ('Element', ('67.19.72.206', 171), 'percentage', 6.107142857142857, '%')
# ('Element', ('184.154.89.154', 168), 'percentage', 6.0, '%')
# ('Element', ('72.20.15.61', 148), 'percentage', 5.285714285714286, '%')
# ('Element', ('46.4.36.120', 77), 'percentage', 2.75, '%')
# ('Element', ('173.192.170.88', 52), 'percentage', 1.8571428571428572, '%')
# ('Element', ('212.117.171.138', 50), 'percentage', 1.7857142857142858, '%')
# ('=======> Value of reservoir:', 2900)
# ('Top 10:', [('193.23.181.44', 359), ('174.128.246.102', 231), ('174.37.196.55', 214), ('173.236.31.226', 197), ('184.154.89.154', 185), ('67.19.72.206', 167), ('72.20.15.61', 165), ('46.4.36.120', 83), ('212.117.171.138', 49), ('147.32.80.9', 43)])
# ('Element', ('193.23.181.44', 359), 'percentage', 12.379310344827585, '%')
# ('Element', ('174.128.246.102', 231), 'percentage', 7.9655172413793105, '%')
# ('Element', ('174.37.196.55', 214), 'percentage', 7.379310344827586, '%')
# ('Element', ('173.236.31.226', 197), 'percentage', 6.793103448275862, '%')
# ('Element', ('184.154.89.154', 185), 'percentage', 6.379310344827586, '%')
# ('Element', ('67.19.72.206', 167), 'percentage', 5.758620689655173, '%')
# ('Element', ('72.20.15.61', 165), 'percentage', 5.689655172413793, '%')
# ('Element', ('46.4.36.120', 83), 'percentage', 2.8620689655172415, '%')
# ('Element', ('212.117.171.138', 49), 'percentage', 1.6896551724137931, '%')
# ('Element', ('147.32.80.9', 43), 'percentage', 1.4827586206896552, '%')
# ('=======> Value of reservoir:', 3000)
# ('Top 10:', [('193.23.181.44', 375), ('174.128.246.102', 246), ('174.37.196.55', 202), ('184.154.89.154', 199), ('173.236.31.226', 193), ('67.19.72.206', 186), ('72.20.15.61', 162), ('46.4.36.120', 79), ('212.117.171.138', 59), ('147.32.80.9', 52)])
# ('Element', ('193.23.181.44', 375), 'percentage', 12.5, '%')
# ('Element', ('174.128.246.102', 246), 'percentage', 8.2, '%')
# ('Element', ('174.37.196.55', 202), 'percentage', 6.733333333333333, '%')
# ('Element', ('184.154.89.154', 199), 'percentage', 6.633333333333334, '%')
# ('Element', ('173.236.31.226', 193), 'percentage', 6.433333333333334, '%')
# ('Element', ('67.19.72.206', 186), 'percentage', 6.2, '%')
# ('Element', ('72.20.15.61', 162), 'percentage', 5.4, '%')
# ('Element', ('46.4.36.120', 79), 'percentage', 2.6333333333333333, '%')
# ('Element', ('212.117.171.138', 59), 'percentage', 1.9666666666666666, '%')
# ('Element', ('147.32.80.9', 52), 'percentage', 1.7333333333333334, '%')
# ('=======> Value of reservoir:', 3100)
# ('Top 10:', [('193.23.181.44', 393), ('174.128.246.102', 239), ('174.37.196.55', 229), ('184.154.89.154', 217), ('173.236.31.226', 205), ('72.20.15.61', 176), ('67.19.72.206', 171), ('46.4.36.120', 92), ('147.32.80.9', 54), ('212.117.171.138', 50)])
# ('Element', ('193.23.181.44', 393), 'percentage', 12.67741935483871, '%')
# ('Element', ('174.128.246.102', 239), 'percentage', 7.709677419354839, '%')
# ('Element', ('174.37.196.55', 229), 'percentage', 7.387096774193548, '%')
# ('Element', ('184.154.89.154', 217), 'percentage', 7.0, '%')
# ('Element', ('173.236.31.226', 205), 'percentage', 6.612903225806452, '%')
# ('Element', ('72.20.15.61', 176), 'percentage', 5.67741935483871, '%')
# ('Element', ('67.19.72.206', 171), 'percentage', 5.516129032258065, '%')
# ('Element', ('46.4.36.120', 92), 'percentage', 2.967741935483871, '%')
# ('Element', ('147.32.80.9', 54), 'percentage', 1.7419354838709677, '%')
# ('Element', ('212.117.171.138', 50), 'percentage', 1.6129032258064515, '%')
# ('=======> Value of reservoir:', 3200)
# ('Top 10:', [('193.23.181.44', 406), ('174.128.246.102', 283), ('174.37.196.55', 222), ('67.19.72.206', 212), ('184.154.89.154', 209), ('72.20.15.61', 193), ('173.236.31.226', 188), ('46.4.36.120', 95), ('212.117.171.138', 66), ('217.163.21.37', 51)])
# ('Element', ('193.23.181.44', 406), 'percentage', 12.6875, '%')
# ('Element', ('174.128.246.102', 283), 'percentage', 8.84375, '%')
# ('Element', ('174.37.196.55', 222), 'percentage', 6.9375, '%')
# ('Element', ('67.19.72.206', 212), 'percentage', 6.625, '%')
# ('Element', ('184.154.89.154', 209), 'percentage', 6.53125, '%')
# ('Element', ('72.20.15.61', 193), 'percentage', 6.03125, '%')
# ('Element', ('173.236.31.226', 188), 'percentage', 5.875, '%')
# ('Element', ('46.4.36.120', 95), 'percentage', 2.96875, '%')
# ('Element', ('212.117.171.138', 66), 'percentage', 2.0625, '%')
# ('Element', ('217.163.21.37', 51), 'percentage', 1.59375, '%')
# ('=======> Value of reservoir:', 3300)
# ('Top 10:', [('193.23.181.44', 430), ('174.128.246.102', 266), ('184.154.89.154', 239), ('174.37.196.55', 236), ('67.19.72.206', 215), ('72.20.15.61', 204), ('173.236.31.226', 200), ('46.4.36.120', 93), ('212.117.171.138', 68), ('147.32.80.9', 52)])
# ('Element', ('193.23.181.44', 430), 'percentage', 13.030303030303031, '%')
# ('Element', ('174.128.246.102', 266), 'percentage', 8.06060606060606, '%')
# ('Element', ('184.154.89.154', 239), 'percentage', 7.242424242424242, '%')
# ('Element', ('174.37.196.55', 236), 'percentage', 7.151515151515151, '%')
# ('Element', ('67.19.72.206', 215), 'percentage', 6.515151515151516, '%')
# ('Element', ('72.20.15.61', 204), 'percentage', 6.181818181818182, '%')
# ('Element', ('173.236.31.226', 200), 'percentage', 6.0606060606060606, '%')
# ('Element', ('46.4.36.120', 93), 'percentage', 2.8181818181818183, '%')
# ('Element', ('212.117.171.138', 68), 'percentage', 2.0606060606060606, '%')
# ('Element', ('147.32.80.9', 52), 'percentage', 1.5757575757575757, '%')
# ('=======> Value of reservoir:', 3400)
# ('Top 10:', [('193.23.181.44', 441), ('174.128.246.102', 268), ('174.37.196.55', 263), ('173.236.31.226', 229), ('184.154.89.154', 209), ('67.19.72.206', 205), ('72.20.15.61', 202), ('46.4.36.120', 100), ('212.117.171.138', 55), ('147.32.80.9', 47)])
# ('Element', ('193.23.181.44', 441), 'percentage', 12.970588235294118, '%')
# ('Element', ('174.128.246.102', 268), 'percentage', 7.882352941176471, '%')
# ('Element', ('174.37.196.55', 263), 'percentage', 7.735294117647059, '%')
# ('Element', ('173.236.31.226', 229), 'percentage', 6.735294117647059, '%')
# ('Element', ('184.154.89.154', 209), 'percentage', 6.147058823529412, '%')
# ('Element', ('67.19.72.206', 205), 'percentage', 6.029411764705882, '%')
# ('Element', ('72.20.15.61', 202), 'percentage', 5.9411764705882355, '%')
# ('Element', ('46.4.36.120', 100), 'percentage', 2.9411764705882355, '%')
# ('Element', ('212.117.171.138', 55), 'percentage', 1.6176470588235294, '%')
# ('Element', ('147.32.80.9', 47), 'percentage', 1.3823529411764706, '%')
# ('=======> Value of reservoir:', 3500)
# ('Top 10:', [('193.23.181.44', 417), ('174.128.246.102', 287), ('184.154.89.154', 254), ('174.37.196.55', 248), ('173.236.31.226', 226), ('67.19.72.206', 216), ('72.20.15.61', 197), ('46.4.36.120', 109), ('212.117.171.138', 60), ('147.32.80.9', 53)])
# ('Element', ('193.23.181.44', 417), 'percentage', 11.914285714285715, '%')
# ('Element', ('174.128.246.102', 287), 'percentage', 8.2, '%')
# ('Element', ('184.154.89.154', 254), 'percentage', 7.257142857142857, '%')
# ('Element', ('174.37.196.55', 248), 'percentage', 7.085714285714285, '%')
# ('Element', ('173.236.31.226', 226), 'percentage', 6.457142857142857, '%')
# ('Element', ('67.19.72.206', 216), 'percentage', 6.171428571428572, '%')
# ('Element', ('72.20.15.61', 197), 'percentage', 5.628571428571429, '%')
# ('Element', ('46.4.36.120', 109), 'percentage', 3.1142857142857143, '%')
# ('Element', ('212.117.171.138', 60), 'percentage', 1.7142857142857142, '%')
# ('Element', ('147.32.80.9', 53), 'percentage', 1.5142857142857142, '%')
# ('=======> Value of reservoir:', 3600)
# ('Top 10:', [('193.23.181.44', 467), ('174.128.246.102', 266), ('174.37.196.55', 261), ('173.236.31.226', 250), ('184.154.89.154', 223), ('72.20.15.61', 216), ('67.19.72.206', 207), ('46.4.36.120', 108), ('212.117.171.138', 69), ('147.32.80.9', 56)])
# ('Element', ('193.23.181.44', 467), 'percentage', 12.972222222222221, '%')
# ('Element', ('174.128.246.102', 266), 'percentage', 7.388888888888889, '%')
# ('Element', ('174.37.196.55', 261), 'percentage', 7.25, '%')
# ('Element', ('173.236.31.226', 250), 'percentage', 6.944444444444445, '%')
# ('Element', ('184.154.89.154', 223), 'percentage', 6.194444444444445, '%')
# ('Element', ('72.20.15.61', 216), 'percentage', 6.0, '%')
# ('Element', ('67.19.72.206', 207), 'percentage', 5.75, '%')
# ('Element', ('46.4.36.120', 108), 'percentage', 3.0, '%')
# ('Element', ('212.117.171.138', 69), 'percentage', 1.9166666666666667, '%')
# ('Element', ('147.32.80.9', 56), 'percentage', 1.5555555555555556, '%')
# ('=======> Value of reservoir:', 3700)
# ('Top 10:', [('193.23.181.44', 439), ('174.128.246.102', 319), ('174.37.196.55', 287), ('173.236.31.226', 253), ('184.154.89.154', 248), ('72.20.15.61', 235), ('67.19.72.206', 217), ('46.4.36.120', 130), ('212.117.171.138', 54), ('147.32.80.9', 51)])
# ('Element', ('193.23.181.44', 439), 'percentage', 11.864864864864865, '%')
# ('Element', ('174.128.246.102', 319), 'percentage', 8.621621621621621, '%')
# ('Element', ('174.37.196.55', 287), 'percentage', 7.756756756756757, '%')
# ('Element', ('173.236.31.226', 253), 'percentage', 6.837837837837838, '%')
# ('Element', ('184.154.89.154', 248), 'percentage', 6.702702702702703, '%')
# ('Element', ('72.20.15.61', 235), 'percentage', 6.351351351351352, '%')
# ('Element', ('67.19.72.206', 217), 'percentage', 5.864864864864865, '%')
# ('Element', ('46.4.36.120', 130), 'percentage', 3.5135135135135136, '%')
# ('Element', ('212.117.171.138', 54), 'percentage', 1.4594594594594594, '%')
# ('Element', ('147.32.80.9', 51), 'percentage', 1.3783783783783783, '%')
# ('=======> Value of reservoir:', 3800)
# ('Top 10:', [('193.23.181.44', 462), ('174.128.246.102', 292), ('184.154.89.154', 258), ('174.37.196.55', 255), ('173.236.31.226', 247), ('67.19.72.206', 229), ('72.20.15.61', 217), ('46.4.36.120', 123), ('212.117.171.138', 70), ('147.32.80.9', 55)])
# ('Element', ('193.23.181.44', 462), 'percentage', 12.157894736842104, '%')
# ('Element', ('174.128.246.102', 292), 'percentage', 7.684210526315789, '%')
# ('Element', ('184.154.89.154', 258), 'percentage', 6.7894736842105265, '%')
# ('Element', ('174.37.196.55', 255), 'percentage', 6.7105263157894735, '%')
# ('Element', ('173.236.31.226', 247), 'percentage', 6.5, '%')
# ('Element', ('67.19.72.206', 229), 'percentage', 6.026315789473684, '%')
# ('Element', ('72.20.15.61', 217), 'percentage', 5.7105263157894735, '%')
# ('Element', ('46.4.36.120', 123), 'percentage', 3.236842105263158, '%')
# ('Element', ('212.117.171.138', 70), 'percentage', 1.8421052631578947, '%')
# ('Element', ('147.32.80.9', 55), 'percentage', 1.4473684210526316, '%')
# ('=======> Value of reservoir:', 3900)
# ('Top 10:', [('193.23.181.44', 474), ('174.128.246.102', 341), ('174.37.196.55', 251), ('184.154.89.154', 247), ('72.20.15.61', 232), ('173.236.31.226', 232), ('67.19.72.206', 229), ('46.4.36.120', 130), ('212.117.171.138', 70), ('173.192.170.88', 54)])
# ('Element', ('193.23.181.44', 474), 'percentage', 12.153846153846153, '%')
# ('Element', ('174.128.246.102', 341), 'percentage', 8.743589743589743, '%')
# ('Element', ('174.37.196.55', 251), 'percentage', 6.435897435897436, '%')
# ('Element', ('184.154.89.154', 247), 'percentage', 6.333333333333333, '%')
# ('Element', ('72.20.15.61', 232), 'percentage', 5.948717948717949, '%')
# ('Element', ('173.236.31.226', 232), 'percentage', 5.948717948717949, '%')
# ('Element', ('67.19.72.206', 229), 'percentage', 5.871794871794871, '%')
# ('Element', ('46.4.36.120', 130), 'percentage', 3.3333333333333335, '%')
# ('Element', ('212.117.171.138', 70), 'percentage', 1.794871794871795, '%')
# ('Element', ('173.192.170.88', 54), 'percentage', 1.3846153846153846, '%')
# ('=======> Value of reservoir:', 4000)
# ('Top 10:', [('193.23.181.44', 503), ('174.128.246.102', 339), ('174.37.196.55', 271), ('184.154.89.154', 260), ('67.19.72.206', 259), ('173.236.31.226', 247), ('72.20.15.61', 234), ('46.4.36.120', 129), ('212.117.171.138', 65), ('147.32.80.9', 64)])
# ('Element', ('193.23.181.44', 503), 'percentage', 12.575, '%')
# ('Element', ('174.128.246.102', 339), 'percentage', 8.475, '%')
# ('Element', ('174.37.196.55', 271), 'percentage', 6.775, '%')
# ('Element', ('184.154.89.154', 260), 'percentage', 6.5, '%')
# ('Element', ('67.19.72.206', 259), 'percentage', 6.475, '%')
# ('Element', ('173.236.31.226', 247), 'percentage', 6.175, '%')
# ('Element', ('72.20.15.61', 234), 'percentage', 5.85, '%')
# ('Element', ('46.4.36.120', 129), 'percentage', 3.225, '%')
# ('Element', ('212.117.171.138', 65), 'percentage', 1.625, '%')
# ('Element', ('147.32.80.9', 64), 'percentage', 1.6, '%')
# ('=======> Value of reservoir:', 4100)
# ('Top 10:', [('193.23.181.44', 513), ('174.37.196.55', 325), ('174.128.246.102', 314), ('173.236.31.226', 285), ('184.154.89.154', 249), ('72.20.15.61', 240), ('67.19.72.206', 231), ('46.4.36.120', 120), ('212.117.171.138', 82), ('147.32.80.9', 70)])
# ('Element', ('193.23.181.44', 513), 'percentage', 12.512195121951219, '%')
# ('Element', ('174.37.196.55', 325), 'percentage', 7.926829268292683, '%')
# ('Element', ('174.128.246.102', 314), 'percentage', 7.658536585365853, '%')
# ('Element', ('173.236.31.226', 285), 'percentage', 6.951219512195122, '%')
# ('Element', ('184.154.89.154', 249), 'percentage', 6.073170731707317, '%')
# ('Element', ('72.20.15.61', 240), 'percentage', 5.853658536585366, '%')
# ('Element', ('67.19.72.206', 231), 'percentage', 5.634146341463414, '%')
# ('Element', ('46.4.36.120', 120), 'percentage', 2.926829268292683, '%')
# ('Element', ('212.117.171.138', 82), 'percentage', 2.0, '%')
# ('Element', ('147.32.80.9', 70), 'percentage', 1.7073170731707317, '%')
# ('=======> Value of reservoir:', 4200)
# ('Top 10:', [('193.23.181.44', 535), ('174.128.246.102', 304), ('184.154.89.154', 290), ('174.37.196.55', 279), ('173.236.31.226', 269), ('67.19.72.206', 254), ('72.20.15.61', 224), ('46.4.36.120', 128), ('147.32.80.9', 83), ('212.117.171.138', 72)])
# ('Element', ('193.23.181.44', 535), 'percentage', 12.738095238095237, '%')
# ('Element', ('174.128.246.102', 304), 'percentage', 7.238095238095238, '%')
# ('Element', ('184.154.89.154', 290), 'percentage', 6.904761904761905, '%')
# ('Element', ('174.37.196.55', 279), 'percentage', 6.642857142857143, '%')
# ('Element', ('173.236.31.226', 269), 'percentage', 6.404761904761905, '%')
# ('Element', ('67.19.72.206', 254), 'percentage', 6.0476190476190474, '%')
# ('Element', ('72.20.15.61', 224), 'percentage', 5.333333333333333, '%')
# ('Element', ('46.4.36.120', 128), 'percentage', 3.0476190476190474, '%')
# ('Element', ('147.32.80.9', 83), 'percentage', 1.9761904761904763, '%')
# ('Element', ('212.117.171.138', 72), 'percentage', 1.7142857142857142, '%')
# ('=======> Value of reservoir:', 4300)
# ('Top 10:', [('193.23.181.44', 514), ('174.37.196.55', 321), ('174.128.246.102', 310), ('184.154.89.154', 289), ('173.236.31.226', 283), ('67.19.72.206', 279), ('72.20.15.61', 240), ('46.4.36.120', 148), ('212.117.171.138', 75), ('147.32.80.9', 59)])
# ('Element', ('193.23.181.44', 514), 'percentage', 11.953488372093023, '%')
# ('Element', ('174.37.196.55', 321), 'percentage', 7.465116279069767, '%')
# ('Element', ('174.128.246.102', 310), 'percentage', 7.209302325581396, '%')
# ('Element', ('184.154.89.154', 289), 'percentage', 6.72093023255814, '%')
# ('Element', ('173.236.31.226', 283), 'percentage', 6.5813953488372094, '%')
# ('Element', ('67.19.72.206', 279), 'percentage', 6.488372093023256, '%')
# ('Element', ('72.20.15.61', 240), 'percentage', 5.5813953488372094, '%')
# ('Element', ('46.4.36.120', 148), 'percentage', 3.441860465116279, '%')
# ('Element', ('212.117.171.138', 75), 'percentage', 1.744186046511628, '%')
# ('Element', ('147.32.80.9', 59), 'percentage', 1.372093023255814, '%')
# ('=======> Value of reservoir:', 4400)
# ('Top 10:', [('193.23.181.44', 582), ('174.128.246.102', 340), ('174.37.196.55', 306), ('184.154.89.154', 285), ('173.236.31.226', 278), ('67.19.72.206', 246), ('72.20.15.61', 242), ('46.4.36.120', 148), ('212.117.171.138', 77), ('173.192.170.88', 56)])
# ('Element', ('193.23.181.44', 582), 'percentage', 13.227272727272727, '%')
# ('Element', ('174.128.246.102', 340), 'percentage', 7.7272727272727275, '%')
# ('Element', ('174.37.196.55', 306), 'percentage', 6.954545454545454, '%')
# ('Element', ('184.154.89.154', 285), 'percentage', 6.4772727272727275, '%')
# ('Element', ('173.236.31.226', 278), 'percentage', 6.318181818181818, '%')
# ('Element', ('67.19.72.206', 246), 'percentage', 5.590909090909091, '%')
# ('Element', ('72.20.15.61', 242), 'percentage', 5.5, '%')
# ('Element', ('46.4.36.120', 148), 'percentage', 3.3636363636363638, '%')
# ('Element', ('212.117.171.138', 77), 'percentage', 1.75, '%')
# ('Element', ('173.192.170.88', 56), 'percentage', 1.2727272727272727, '%')
# ('=======> Value of reservoir:', 4500)
# ('Top 10:', [('193.23.181.44', 577), ('174.128.246.102', 341), ('174.37.196.55', 336), ('184.154.89.154', 303), ('173.236.31.226', 296), ('67.19.72.206', 279), ('72.20.15.61', 271), ('46.4.36.120', 135), ('212.117.171.138', 87), ('147.32.80.9', 70)])
# ('Element', ('193.23.181.44', 577), 'percentage', 12.822222222222223, '%')
# ('Element', ('174.128.246.102', 341), 'percentage', 7.5777777777777775, '%')
# ('Element', ('174.37.196.55', 336), 'percentage', 7.466666666666667, '%')
# ('Element', ('184.154.89.154', 303), 'percentage', 6.733333333333333, '%')
# ('Element', ('173.236.31.226', 296), 'percentage', 6.5777777777777775, '%')
# ('Element', ('67.19.72.206', 279), 'percentage', 6.2, '%')
# ('Element', ('72.20.15.61', 271), 'percentage', 6.022222222222222, '%')
# ('Element', ('46.4.36.120', 135), 'percentage', 3.0, '%')
# ('Element', ('212.117.171.138', 87), 'percentage', 1.9333333333333333, '%')
# ('Element', ('147.32.80.9', 70), 'percentage', 1.5555555555555556, '%')
# ('=======> Value of reservoir:', 4600)
# ('Top 10:', [('193.23.181.44', 581), ('174.128.246.102', 388), ('174.37.196.55', 323), ('184.154.89.154', 293), ('67.19.72.206', 291), ('173.236.31.226', 268), ('72.20.15.61', 237), ('46.4.36.120', 147), ('212.117.171.138', 92), ('147.32.80.9', 82)])
# ('Element', ('193.23.181.44', 581), 'percentage', 12.630434782608695, '%')
# ('Element', ('174.128.246.102', 388), 'percentage', 8.434782608695652, '%')
# ('Element', ('174.37.196.55', 323), 'percentage', 7.021739130434782, '%')
# ('Element', ('184.154.89.154', 293), 'percentage', 6.369565217391305, '%')
# ('Element', ('67.19.72.206', 291), 'percentage', 6.326086956521739, '%')
# ('Element', ('173.236.31.226', 268), 'percentage', 5.826086956521739, '%')
# ('Element', ('72.20.15.61', 237), 'percentage', 5.1521739130434785, '%')
# ('Element', ('46.4.36.120', 147), 'percentage', 3.1956521739130435, '%')
# ('Element', ('212.117.171.138', 92), 'percentage', 2.0, '%')
# ('Element', ('147.32.80.9', 82), 'percentage', 1.7826086956521738, '%')
# ('=======> Value of reservoir:', 4700)
# ('Top 10:', [('193.23.181.44', 579), ('174.128.246.102', 375), ('173.236.31.226', 358), ('174.37.196.55', 312), ('184.154.89.154', 284), ('67.19.72.206', 278), ('72.20.15.61', 274), ('46.4.36.120', 146), ('212.117.171.138', 80), ('173.192.170.88', 70)])
# ('Element', ('193.23.181.44', 579), 'percentage', 12.319148936170214, '%')
# ('Element', ('174.128.246.102', 375), 'percentage', 7.9787234042553195, '%')
# ('Element', ('173.236.31.226', 358), 'percentage', 7.617021276595745, '%')
# ('Element', ('174.37.196.55', 312), 'percentage', 6.638297872340425, '%')
# ('Element', ('184.154.89.154', 284), 'percentage', 6.042553191489362, '%')
# ('Element', ('67.19.72.206', 278), 'percentage', 5.914893617021277, '%')
# ('Element', ('72.20.15.61', 274), 'percentage', 5.829787234042553, '%')
# ('Element', ('46.4.36.120', 146), 'percentage', 3.106382978723404, '%')
# ('Element', ('212.117.171.138', 80), 'percentage', 1.702127659574468, '%')
# ('Element', ('173.192.170.88', 70), 'percentage', 1.4893617021276595, '%')
# ('=======> Value of reservoir:', 4800)
# ('Top 10:', [('193.23.181.44', 611), ('174.128.246.102', 404), ('174.37.196.55', 326), ('72.20.15.61', 295), ('173.236.31.226', 290), ('184.154.89.154', 287), ('67.19.72.206', 278), ('46.4.36.120', 150), ('147.32.80.9', 84), ('212.117.171.138', 73)])
# ('Element', ('193.23.181.44', 611), 'percentage', 12.729166666666666, '%')
# ('Element', ('174.128.246.102', 404), 'percentage', 8.416666666666666, '%')
# ('Element', ('174.37.196.55', 326), 'percentage', 6.791666666666667, '%')
# ('Element', ('72.20.15.61', 295), 'percentage', 6.145833333333333, '%')
# ('Element', ('173.236.31.226', 290), 'percentage', 6.041666666666667, '%')
# ('Element', ('184.154.89.154', 287), 'percentage', 5.979166666666667, '%')
# ('Element', ('67.19.72.206', 278), 'percentage', 5.791666666666667, '%')
# ('Element', ('46.4.36.120', 150), 'percentage', 3.125, '%')
# ('Element', ('147.32.80.9', 84), 'percentage', 1.75, '%')
# ('Element', ('212.117.171.138', 73), 'percentage', 1.5208333333333333, '%')
# ('=======> Value of reservoir:', 4900)
# ('Top 10:', [('193.23.181.44', 621), ('174.128.246.102', 371), ('174.37.196.55', 343), ('184.154.89.154', 321), ('173.236.31.226', 302), ('67.19.72.206', 291), ('72.20.15.61', 289), ('46.4.36.120', 161), ('212.117.171.138', 88), ('173.192.170.88', 72)])
# ('Element', ('193.23.181.44', 621), 'percentage', 12.673469387755102, '%')
# ('Element', ('174.128.246.102', 371), 'percentage', 7.571428571428571, '%')
# ('Element', ('174.37.196.55', 343), 'percentage', 7.0, '%')
# ('Element', ('184.154.89.154', 321), 'percentage', 6.551020408163265, '%')
# ('Element', ('173.236.31.226', 302), 'percentage', 6.163265306122449, '%')
# ('Element', ('67.19.72.206', 291), 'percentage', 5.938775510204081, '%')
# ...
# ('Element', ('193.23.181.44', 1039), 'percentage', 12.223529411764705, '%')
# ('Element', ('174.128.246.102', 667), 'percentage', 7.847058823529411, '%')
# ('Element', ('174.37.196.55', 604), 'percentage', 7.105882352941176, '%')
# ('Element', ('173.236.31.226', 564), 'percentage', 6.635294117647059, '%')
# ('Element', ('184.154.89.154', 558), 'percentage', 6.564705882352941, '%')
# ('Element', ('67.19.72.206', 547), 'percentage', 6.435294117647059, '%')
# ('Element', ('72.20.15.61', 480), 'percentage', 5.647058823529412, '%')
# ('Element', ('46.4.36.120', 279), 'percentage', 3.2823529411764705, '%')
# ('Element', ('212.117.171.138', 159), 'percentage', 1.8705882352941177, '%')
# ('Element', ('147.32.80.9', 136), 'percentage', 1.6, '%')
# ('=======> Value of reservoir:', 8600)
# ('Top 10:', [('193.23.181.44', 1073), ('174.128.246.102', 707), ('174.37.196.55', 646), ('173.236.31.226', 601), ('72.20.15.61', 531), ('184.154.89.154', 524), ('67.19.72.206', 486), ('46.4.36.120', 259), ('212.117.171.138', 151), ('147.32.80.9', 140)])
# ('Element', ('193.23.181.44', 1073), 'percentage', 12.476744186046512, '%')
# ('Element', ('174.128.246.102', 707), 'percentage', 8.220930232558139, '%')
# ('Element', ('174.37.196.55', 646), 'percentage', 7.511627906976744, '%')
# ('Element', ('173.236.31.226', 601), 'percentage', 6.988372093023256, '%')
# ('Element', ('72.20.15.61', 531), 'percentage', 6.174418604651163, '%')
# ('Element', ('184.154.89.154', 524), 'percentage', 6.093023255813954, '%')
# ('Element', ('67.19.72.206', 486), 'percentage', 5.651162790697675, '%')
# ('Element', ('46.4.36.120', 259), 'percentage', 3.011627906976744, '%')
# ('Element', ('212.117.171.138', 151), 'percentage', 1.755813953488372, '%')
# ('Element', ('147.32.80.9', 140), 'percentage', 1.627906976744186, '%')
# ('=======> Value of reservoir:', 8700)
# ('Top 10:', [('193.23.181.44', 1044), ('174.128.246.102', 676), ('174.37.196.55', 637), ('184.154.89.154', 608), ('173.236.31.226', 600), ('67.19.72.206', 524), ('72.20.15.61', 469), ('46.4.36.120', 281), ('212.117.171.138', 167), ('147.32.80.9', 136)])
# ('Element', ('193.23.181.44', 1044), 'percentage', 12.0, '%')
# ('Element', ('174.128.246.102', 676), 'percentage', 7.7701149425287355, '%')
# ('Element', ('174.37.196.55', 637), 'percentage', 7.32183908045977, '%')
# ('Element', ('184.154.89.154', 608), 'percentage', 6.988505747126437, '%')
# ('Element', ('173.236.31.226', 600), 'percentage', 6.896551724137931, '%')
# ('Element', ('67.19.72.206', 524), 'percentage', 6.022988505747127, '%')
# ('Element', ('72.20.15.61', 469), 'percentage', 5.390804597701149, '%')
# ('Element', ('46.4.36.120', 281), 'percentage', 3.2298850574712645, '%')
# ('Element', ('212.117.171.138', 167), 'percentage', 1.9195402298850575, '%')
# ('Element', ('147.32.80.9', 136), 'percentage', 1.5632183908045978, '%')
# ('=======> Value of reservoir:', 8800)
# ('Top 10:', [('193.23.181.44', 1068), ('174.128.246.102', 698), ('174.37.196.55', 631), ('173.236.31.226', 572), ('67.19.72.206', 559), ('184.154.89.154', 549), ('72.20.15.61', 501), ('46.4.36.120', 267), ('212.117.171.138', 142), ('147.32.80.9', 140)])
# ('Element', ('193.23.181.44', 1068), 'percentage', 12.136363636363637, '%')
# ('Element', ('174.128.246.102', 698), 'percentage', 7.931818181818182, '%')
# ('Element', ('174.37.196.55', 631), 'percentage', 7.170454545454546, '%')
# ('Element', ('173.236.31.226', 572), 'percentage', 6.5, '%')
# ('Element', ('67.19.72.206', 559), 'percentage', 6.3522727272727275, '%')
# ('Element', ('184.154.89.154', 549), 'percentage', 6.238636363636363, '%')
# ('Element', ('72.20.15.61', 501), 'percentage', 5.693181818181818, '%')
# ('Element', ('46.4.36.120', 267), 'percentage', 3.034090909090909, '%')
# ('Element', ('212.117.171.138', 142), 'percentage', 1.6136363636363635, '%')
# ('Element', ('147.32.80.9', 140), 'percentage', 1.5909090909090908, '%')
# ('=======> Value of reservoir:', 8900)
# ('Top 10:', [('193.23.181.44', 1147), ('174.128.246.102', 716), ('174.37.196.55', 658), ('184.154.89.154', 572), ('173.236.31.226', 572), ('67.19.72.206', 549), ('72.20.15.61', 500), ('46.4.36.120', 279), ('212.117.171.138', 170), ('147.32.80.9', 142)])
# ('Element', ('193.23.181.44', 1147), 'percentage', 12.887640449438202, '%')
# ('Element', ('174.128.246.102', 716), 'percentage', 8.044943820224718, '%')
# ('Element', ('174.37.196.55', 658), 'percentage', 7.393258426966292, '%')
# ('Element', ('184.154.89.154', 572), 'percentage', 6.426966292134831, '%')
# ('Element', ('173.236.31.226', 572), 'percentage', 6.426966292134831, '%')
# ('Element', ('67.19.72.206', 549), 'percentage', 6.168539325842697, '%')
# ('Element', ('72.20.15.61', 500), 'percentage', 5.617977528089888, '%')
# ('Element', ('46.4.36.120', 279), 'percentage', 3.134831460674157, '%')
# ('Element', ('212.117.171.138', 170), 'percentage', 1.9101123595505618, '%')
# ('Element', ('147.32.80.9', 142), 'percentage', 1.595505617977528, '%')
# ('=======> Value of reservoir:', 9000)
# ('Top 10:', [('193.23.181.44', 1101), ('174.128.246.102', 730), ('174.37.196.55', 649), ('173.236.31.226', 586), ('184.154.89.154', 582), ('67.19.72.206', 546), ('72.20.15.61', 504), ('46.4.36.120', 301), ('212.117.171.138', 162), ('147.32.80.9', 127)])
# ('Element', ('193.23.181.44', 1101), 'percentage', 12.233333333333333, '%')
# ('Element', ('174.128.246.102', 730), 'percentage', 8.11111111111111, '%')
# ('Element', ('174.37.196.55', 649), 'percentage', 7.211111111111111, '%')
# ('Element', ('173.236.31.226', 586), 'percentage', 6.511111111111111, '%')
# ('Element', ('184.154.89.154', 582), 'percentage', 6.466666666666667, '%')
# ('Element', ('67.19.72.206', 546), 'percentage', 6.066666666666666, '%')
# ('Element', ('72.20.15.61', 504), 'percentage', 5.6, '%')
# ('Element', ('46.4.36.120', 301), 'percentage', 3.3444444444444446, '%')
# ('Element', ('212.117.171.138', 162), 'percentage', 1.8, '%')
# ('Element', ('147.32.80.9', 127), 'percentage', 1.4111111111111112, '%')
# ('=======> Value of reservoir:', 9100)
# ('Top 10:', [('193.23.181.44', 1155), ('174.128.246.102', 755), ('173.236.31.226', 619), ('174.37.196.55', 607), ('184.154.89.154', 581), ('67.19.72.206', 539), ('72.20.15.61', 502), ('46.4.36.120', 291), ('212.117.171.138', 173), ('147.32.80.9', 142)])
# ('Element', ('193.23.181.44', 1155), 'percentage', 12.692307692307692, '%')
# ('Element', ('174.128.246.102', 755), 'percentage', 8.296703296703297, '%')
# ('Element', ('173.236.31.226', 619), 'percentage', 6.802197802197802, '%')
# ('Element', ('174.37.196.55', 607), 'percentage', 6.670329670329671, '%')
# ('Element', ('184.154.89.154', 581), 'percentage', 6.384615384615385, '%')
# ('Element', ('67.19.72.206', 539), 'percentage', 5.923076923076923, '%')
# ('Element', ('72.20.15.61', 502), 'percentage', 5.516483516483516, '%')
# ('Element', ('46.4.36.120', 291), 'percentage', 3.197802197802198, '%')
# ('Element', ('212.117.171.138', 173), 'percentage', 1.901098901098901, '%')
# ('Element', ('147.32.80.9', 142), 'percentage', 1.5604395604395604, '%')
# ('=======> Value of reservoir:', 9200)
# ('Top 10:', [('193.23.181.44', 1210), ('174.128.246.102', 717), ('173.236.31.226', 643), ('174.37.196.55', 632), ('184.154.89.154', 608), ('67.19.72.206', 562), ('72.20.15.61', 520), ('46.4.36.120', 307), ('212.117.171.138', 161), ('147.32.80.9', 138)])
# ('Element', ('193.23.181.44', 1210), 'percentage', 13.152173913043478, '%')
# ('Element', ('174.128.246.102', 717), 'percentage', 7.793478260869565, '%')
# ('Element', ('173.236.31.226', 643), 'percentage', 6.989130434782608, '%')
# ('Element', ('174.37.196.55', 632), 'percentage', 6.869565217391305, '%')
# ('Element', ('184.154.89.154', 608), 'percentage', 6.608695652173913, '%')
# ('Element', ('67.19.72.206', 562), 'percentage', 6.108695652173913, '%')
# ('Element', ('72.20.15.61', 520), 'percentage', 5.6521739130434785, '%')
# ('Element', ('46.4.36.120', 307), 'percentage', 3.3369565217391304, '%')
# ('Element', ('212.117.171.138', 161), 'percentage', 1.75, '%')
# ('Element', ('147.32.80.9', 138), 'percentage', 1.5, '%')
# ('=======> Value of reservoir:', 9300)
# ('Top 10:', [('193.23.181.44', 1186), ('174.128.246.102', 684), ('174.37.196.55', 657), ('173.236.31.226', 604), ('184.154.89.154', 579), ('67.19.72.206', 577), ('72.20.15.61', 522), ('46.4.36.120', 306), ('212.117.171.138', 210), ('217.163.21.37', 142)])
# ('Element', ('193.23.181.44', 1186), 'percentage', 12.75268817204301, '%')
# ('Element', ('174.128.246.102', 684), 'percentage', 7.354838709677419, '%')
# ('Element', ('174.37.196.55', 657), 'percentage', 7.064516129032258, '%')
# ('Element', ('173.236.31.226', 604), 'percentage', 6.494623655913978, '%')
# ('Element', ('184.154.89.154', 579), 'percentage', 6.225806451612903, '%')
# ('Element', ('67.19.72.206', 577), 'percentage', 6.204301075268817, '%')
# ('Element', ('72.20.15.61', 522), 'percentage', 5.612903225806452, '%')
# ('Element', ('46.4.36.120', 306), 'percentage', 3.2903225806451615, '%')
# ('Element', ('212.117.171.138', 210), 'percentage', 2.2580645161290325, '%')
# ('Element', ('217.163.21.37', 142), 'percentage', 1.5268817204301075, '%')
# ('=======> Value of reservoir:', 9400)
# ('Top 10:', [('193.23.181.44', 1175), ('174.128.246.102', 749), ('174.37.196.55', 694), ('184.154.89.154', 627), ('67.19.72.206', 590), ('173.236.31.226', 562), ('72.20.15.61', 530), ('46.4.36.120', 290), ('212.117.171.138', 187), ('147.32.80.9', 139)])
# ('Element', ('193.23.181.44', 1175), 'percentage', 12.5, '%')
# ('Element', ('174.128.246.102', 749), 'percentage', 7.968085106382978, '%')
# ('Element', ('174.37.196.55', 694), 'percentage', 7.382978723404255, '%')
# ('Element', ('184.154.89.154', 627), 'percentage', 6.670212765957447, '%')
# ('Element', ('67.19.72.206', 590), 'percentage', 6.276595744680851, '%')
# ('Element', ('173.236.31.226', 562), 'percentage', 5.9787234042553195, '%')
# ('Element', ('72.20.15.61', 530), 'percentage', 5.638297872340425, '%')
# ('Element', ('46.4.36.120', 290), 'percentage', 3.0851063829787235, '%')
# ('Element', ('212.117.171.138', 187), 'percentage', 1.9893617021276595, '%')
# ('Element', ('147.32.80.9', 139), 'percentage', 1.4787234042553192, '%')
# ('=======> Value of reservoir:', 9500)
# ('Top 10:', [('193.23.181.44', 1157), ('174.128.246.102', 786), ('174.37.196.55', 665), ('173.236.31.226', 609), ('184.154.89.154', 579), ('67.19.72.206', 554), ('72.20.15.61', 532), ('46.4.36.120', 296), ('212.117.171.138', 162), ('217.163.21.37', 149)])
# ('Element', ('193.23.181.44', 1157), 'percentage', 12.178947368421053, '%')
# ('Element', ('174.128.246.102', 786), 'percentage', 8.273684210526316, '%')
# ('Element', ('174.37.196.55', 665), 'percentage', 7.0, '%')
# ('Element', ('173.236.31.226', 609), 'percentage', 6.410526315789474, '%')
# ('Element', ('184.154.89.154', 579), 'percentage', 6.094736842105263, '%')
# ('Element', ('67.19.72.206', 554), 'percentage', 5.831578947368421, '%')
# ('Element', ('72.20.15.61', 532), 'percentage', 5.6, '%')
# ('Element', ('46.4.36.120', 296), 'percentage', 3.1157894736842104, '%')
# ('Element', ('212.117.171.138', 162), 'percentage', 1.7052631578947368, '%')
# ('Element', ('217.163.21.37', 149), 'percentage', 1.568421052631579, '%')
# ('=======> Value of reservoir:', 9600)
# ('Top 10:', [('193.23.181.44', 1195), ('174.128.246.102', 725), ('174.37.196.55', 716), ('173.236.31.226', 627), ('184.154.89.154', 624), ('67.19.72.206', 584), ('72.20.15.61', 577), ('46.4.36.120', 333), ('212.117.171.138', 190), ('147.32.80.9', 143)])
# ('Element', ('193.23.181.44', 1195), 'percentage', 12.447916666666666, '%')
# ('Element', ('174.128.246.102', 725), 'percentage', 7.552083333333333, '%')
# ('Element', ('174.37.196.55', 716), 'percentage', 7.458333333333333, '%')
# ('Element', ('173.236.31.226', 627), 'percentage', 6.53125, '%')
# ('Element', ('184.154.89.154', 624), 'percentage', 6.5, '%')
# ('Element', ('67.19.72.206', 584), 'percentage', 6.083333333333333, '%')
# ('Element', ('72.20.15.61', 577), 'percentage', 6.010416666666667, '%')
# ('Element', ('46.4.36.120', 333), 'percentage', 3.46875, '%')
# ('Element', ('212.117.171.138', 190), 'percentage', 1.9791666666666667, '%')
# ('Element', ('147.32.80.9', 143), 'percentage', 1.4895833333333333, '%')
# ('=======> Value of reservoir:', 9700)
# ('Top 10:', [('193.23.181.44', 1198), ('174.128.246.102', 743), ('174.37.196.55', 687), ('173.236.31.226', 663), ('184.154.89.154', 650), ('67.19.72.206', 623), ('72.20.15.61', 530), ('46.4.36.120', 302), ('212.117.171.138', 161), ('147.32.80.9', 154)])
# ('Element', ('193.23.181.44', 1198), 'percentage', 12.350515463917526, '%')
# ('Element', ('174.128.246.102', 743), 'percentage', 7.65979381443299, '%')
# ('Element', ('174.37.196.55', 687), 'percentage', 7.082474226804123, '%')
# ('Element', ('173.236.31.226', 663), 'percentage', 6.835051546391752, '%')
# ('Element', ('184.154.89.154', 650), 'percentage', 6.701030927835052, '%')
# ('Element', ('67.19.72.206', 623), 'percentage', 6.422680412371134, '%')
# ('Element', ('72.20.15.61', 530), 'percentage', 5.463917525773196, '%')
# ('Element', ('46.4.36.120', 302), 'percentage', 3.11340206185567, '%')
# ('Element', ('212.117.171.138', 161), 'percentage', 1.6597938144329898, '%')
# ('Element', ('147.32.80.9', 154), 'percentage', 1.5876288659793814, '%')
# ('=======> Value of reservoir:', 9800)
# ('Top 10:', [('193.23.181.44', 1206), ('174.128.246.102', 761), ('174.37.196.55', 701), ('173.236.31.226', 664), ('184.154.89.154', 609), ('67.19.72.206', 603), ('72.20.15.61', 565), ('46.4.36.120', 297), ('212.117.171.138', 177), ('173.192.170.88', 151)])
# ('Element', ('193.23.181.44', 1206), 'percentage', 12.306122448979592, '%')
# ('Element', ('174.128.246.102', 761), 'percentage', 7.76530612244898, '%')
# ('Element', ('174.37.196.55', 701), 'percentage', 7.153061224489796, '%')
# ('Element', ('173.236.31.226', 664), 'percentage', 6.775510204081633, '%')
# ('Element', ('184.154.89.154', 609), 'percentage', 6.214285714285714, '%')
# ('Element', ('67.19.72.206', 603), 'percentage', 6.153061224489796, '%')
# ('Element', ('72.20.15.61', 565), 'percentage', 5.76530612244898, '%')
# ('Element', ('46.4.36.120', 297), 'percentage', 3.0306122448979593, '%')
# ('Element', ('212.117.171.138', 177), 'percentage', 1.8061224489795917, '%')
# ('Element', ('173.192.170.88', 151), 'percentage', 1.5408163265306123, '%')
# ('=======> Value of reservoir:', 9900)
# ('Top 10:', [('193.23.181.44', 1229), ('174.128.246.102', 804), ('174.37.196.55', 716), ('184.154.89.154', 633), ('173.236.31.226', 622), ('67.19.72.206', 621), ('72.20.15.61', 555), ('46.4.36.120', 307), ('212.117.171.138', 182), ('147.32.80.9', 142)])
# ('Element', ('193.23.181.44', 1229), 'percentage', 12.414141414141413, '%')
# ('Element', ('174.128.246.102', 804), 'percentage', 8.121212121212121, '%')
# ('Element', ('174.37.196.55', 716), 'percentage', 7.232323232323233, '%')
# ('Element', ('184.154.89.154', 633), 'percentage', 6.393939393939394, '%')
# ('Element', ('173.236.31.226', 622), 'percentage', 6.282828282828283, '%')
# ('Element', ('67.19.72.206', 621), 'percentage', 6.2727272727272725, '%')
# ('Element', ('72.20.15.61', 555), 'percentage', 5.606060606060606, '%')
# ('Element', ('46.4.36.120', 307), 'percentage', 3.101010101010101, '%')
# ('Element', ('212.117.171.138', 182), 'percentage', 1.8383838383838385, '%')
# ('Element', ('147.32.80.9', 142), 'percentage', 1.4343434343434343, '%')
# ('=======> Value of reservoir:', 10000)
# ('Top 10:', [('193.23.181.44', 1236), ('174.128.246.102', 807), ('174.37.196.55', 666), ('173.236.31.226', 635), ('184.154.89.154', 631), ('67.19.72.206', 614), ('72.20.15.61', 583), ('46.4.36.120', 310), ('212.117.171.138', 176), ('147.32.80.9', 154)])
# ('Element', ('193.23.181.44', 1236), 'percentage', 12.36, '%')
# ('Element', ('174.128.246.102', 807), 'percentage', 8.07, '%')
# ('Element', ('174.37.196.55', 666), 'percentage', 6.66, '%')
# ('Element', ('173.236.31.226', 635), 'percentage', 6.35, '%')
# ('Element', ('184.154.89.154', 631), 'percentage', 6.31, '%')
# ('Element', ('67.19.72.206', 614), 'percentage', 6.14, '%')
# ('Element', ('72.20.15.61', 583), 'percentage', 5.83, '%')
# ('Element', ('46.4.36.120', 310), 'percentage', 3.1, '%')
# ('Element', ('212.117.171.138', 176), 'percentage', 1.76, '%')
# ('Element', ('147.32.80.9', 154), 'percentage', 1.54, '%')

# %% [markdown]
# ## The 10 most frequent ips with COUNT-MIN sketching for different w, d

# %%
#start the min-count sketch
class CountMin:
    
    def __init__(self, w, d):
        self.size = w*d
        self.w = w
        self.hash_count = d
        self.cm_array =  [[0]*w for i in range(d)]
        
    def add(self, string):
        for seed in range(self.hash_count):
            result = mmh3.hash(string, seed) % self.w
            self.cm_array[seed][result] += 1
        
    def point(self, string):
        min = 9999999
        for seed in range(self.hash_count):
            result = mmh3.hash(string, seed) % self.w
            if self.cm_array[seed][result]<min:
                min = self.cm_array[seed][result]
        return min

# %%
e = 2.718281828

# compute the frequnt ips for different values of d and w
for epsilon in [0.0001, 0.001, 0.005, 0.01, 0.1]:
    for delta in [0.0001, 0.001, 0.005, 0.01, 0.1]:
        
        # calculate the w, d
        w = round(e/epsilon)
        d = round(math.log(1/delta))

        # construct the matrix with the correct dimensions
        count_min_matrix = CountMin(int(w), int(d))

        # add each ip to the matrix
        for ip in ips:
                count_min_matrix.add(ip)
                
        # find frequency and store it to cm_res
        count_min = {}
        for ip in ips:
            count_min[ip] = count_min_matrix.point(ip)

        # sort them according to their value to find the 10 most frequent ones
        sorted_count_min = sorted(count_min.items(), key=operator.itemgetter(1), reverse = True)

        difference_w_ground = 0
        for i in range(10):
            #find the difference between the count min and the ground truth
            difference_w_ground+= abs(sorted_count_min[i][1] - most_freq[i][1])

        print('For w=', w, 'and d=', d, 'accuracy', 100-(difference_w_ground*100.0/51809),'%')
        print('epsilon= ',epsilon, 'and delta=', delta)
# Out:
# ('For w=', 27183.0, 'and d=', 9.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.0001, 'and delta=', 0.0001)
# ('For w=', 27183.0, 'and d=', 7.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.0001, 'and delta=', 0.001)
# ('For w=', 27183.0, 'and d=', 5.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.0001, 'and delta=', 0.005)
# ('For w=', 27183.0, 'and d=', 5.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.0001, 'and delta=', 0.01)
# ('For w=', 27183.0, 'and d=', 2.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.0001, 'and delta=', 0.1)
# ('For w=', 2718.0, 'and d=', 9.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.001, 'and delta=', 0.0001)
# ('For w=', 2718.0, 'and d=', 7.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.001, 'and delta=', 0.001)
# ('For w=', 2718.0, 'and d=', 5.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.001, 'and delta=', 0.005)
# ('For w=', 2718.0, 'and d=', 5.0, 'accuracy', 100.0, '%')
# ('epsilon= ', 0.001, 'and delta=', 0.01)
# ('For w=', 2718.0, 'and d=', 2.0, 'accuracy', 99.99613966685325, '%')
# ('epsilon= ', 0.001, 'and delta=', 0.1)
# ('For w=', 544.0, 'and d=', 9.0, 'accuracy', 99.9459553359455, '%')
# ('epsilon= ', 0.005, 'and delta=', 0.0001)
# ('For w=', 544.0, 'and d=', 7.0, 'accuracy', 99.93630450307862, '%')
# ('epsilon= ', 0.005, 'and delta=', 0.001)
# ('For w=', 544.0, 'and d=', 5.0, 'accuracy', 99.90928217105136, '%')
# ('epsilon= ', 0.005, 'and delta=', 0.005)
# ('For w=', 544.0, 'and d=', 5.0, 'accuracy', 99.90928217105136, '%')
# ('epsilon= ', 0.005, 'and delta=', 0.01)
# ('For w=', 544.0, 'and d=', 2.0, 'accuracy', 99.14493620799475, '%')
# ('epsilon= ', 0.005, 'and delta=', 0.1)
# ('For w=', 272.0, 'and d=', 9.0, 'accuracy', 99.83014534154297, '%')
# ('epsilon= ', 0.01, 'and delta=', 0.0001)
# ('For w=', 272.0, 'and d=', 7.0, 'accuracy', 99.82435484182285, '%')
# ('epsilon= ', 0.01, 'and delta=', 0.001)
# ('For w=', 272.0, 'and d=', 5.0, 'accuracy', 99.69117334825995, '%')
# ('epsilon= ', 0.01, 'and delta=', 0.005)
# ('For w=', 272.0, 'and d=', 5.0, 'accuracy', 99.69117334825995, '%')
# ('epsilon= ', 0.01, 'and delta=', 0.01)
# ('For w=', 272.0, 'and d=', 2.0, 'accuracy', 89.57710050377348, '%')
# ('epsilon= ', 0.01, 'and delta=', 0.1)
# ('For w=', 27.0, 'and d=', 9.0, 'accuracy', 93.5493833117798, '%')
# ('epsilon= ', 0.1, 'and delta=', 0.0001)
# ('For w=', 27.0, 'and d=', 7.0, 'accuracy', 91.37408558358587, '%')
# ('epsilon= ', 0.1, 'and delta=', 0.001)
# ('For w=', 27.0, 'and d=', 5.0, 'accuracy', 88.66027138142022, '%')
# ('epsilon= ', 0.1, 'and delta=', 0.005)
# ('For w=', 27.0, 'and d=', 5.0, 'accuracy', 88.66027138142022, '%')
# ('epsilon= ', 0.1, 'and delta=', 0.01)
# ('For w=', 27.0, 'and d=', 2.0, 'accuracy', 49.67476693238626, '%')
# ('epsilon= ', 0.1, 'and delta=', 0.1)

# %% [markdown]
# ### Compare the run time for the two implemented methods

# %%
import timeit

start_min_wise = timeit.default_timer()

k=5000
for index, row in infected_dataset.iterrows():
    #begin by setting a random value at each row
    a = random.uniform(0,1)
    infected_dataset.set_value(index,'rn',a)

sort_infections = infected_dataset.sort_values(['rn'], ascending=[True])
sel_k = sort_infections[0:k]
sel_k=sel_k.reset_index(level=0, drop=True)
most_freq_minwise, ips_minwise = return_k_frequent_ips(sel_k, 10)


stop_min_wise = timeit.default_timer()
min_wise_time = stop_min_wise - start_min_wise


start_count_min = timeit.default_timer()

w = 2718
d = 4
# construct the matrix with the correct dimensions
count_min_matrix = CountMin(int(w), int(d))

# add each ip to the matrix
for ip in ips:
        count_min_matrix.add(ip)

# find frequency and store it to cm_res
count_min = {}
for ip in ips:
    count_min[ip] = count_min_matrix.point(ip)

# sort them according to their value to find the 10 most frequent ones
sorted_count_min = sorted(count_min.items(), key=operator.itemgetter(1), reverse = True)

stop_count_min = timeit.default_timer()

count_min_time = stop_count_min - start_count_min
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':

# %%
print(min_wise_time, count_min_time)
# Out:
# (4.7074267864227295, 0.34471797943115234)
